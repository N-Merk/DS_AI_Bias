# %%
import pandas as pd
from src.comparison_different_df import plot_gender_distribution_comparison
from data.raw.professions import df_female, df_male

# %% [markdown]
# # Check the difference of the prompts

# %%
df_neutral = pd.read_csv("../data/processed/translated_df_neutral.csv")
df_feminist = pd.read_csv("../data/processed/translated_df_feminist.csv")
df_incel = pd.read_csv("../data/processed/translated_df_incel.csv")
df_real = pd.concat([df_female, df_male], ignore_index=True)

# %%
datasets = {
    "neutral": df_neutral,
    "feminist": df_feminist,
    "incel": df_incel
}

plot_gender_distribution_comparison(datasets, df_real, "df_neutral_feminist_incel")
